# %%
import geopandas as gpd
from glob import glob
import os
from matplotlib import pyplot as plt

# %%
eco_shp = '../na_cec_eco_l1/NA_CEC_Eco_Level1.shp'
df_eco = gpd.read_file(eco_shp)

# %%
us_boundary = gpd.read_file('../CONUS_boundary/CONUS_boundary.shp')

# %%
us_boundary.plot()

# %%
us_boundary.crs, df_eco.crs
# Out:
# ({'init': 'epsg:3857'},
#  {'proj': 'laea',
#   'lat_0': 45,
#   'lon_0': -100,
#   'x_0': 0,
#   'y_0': 0,
#   'a': 6370997,
#   'b': 6370997,
#   'units': 'm',
#   'no_defs': True})

# %%
from earthpy.clip import clip_shp

# %%
test = clip_shp(df_eco.to_crs(epsg=3857), us_boundary).reset_index()

# %%
test.plot(column="NA_L1NAME", figsize=(10,10), legend=True)

# %%
from helpers import clip_points_by_ecoregion
from glob import glob
import multiprocessing as mp
from functools import partial

# %%
output_folder = '../epa_L1_ecoregion_points'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    
fire_pts_folders = !ls -d ../modis_fire_points/*
shp_files = [glob(folder + '/*.shp')[0] for folder in fire_pts_folders]

## group the ecoregions by name
groups = test.to_crs(epsg=4326).groupby('NA_L1NAME')

# %%
num_cpu = mp.cpu_count() - 2
num_cpu = 3
pool = mp.Pool(processes=num_cpu)

for group in groups:
    a = pool.map(partial(clip_points_by_ecoregion, group=group, out_folder=output_folder), shp_files)

pool.close()
pool.join()

# %%
clip_points_by_ecoregion(shp_files[0], list(groups)[0], output_folder)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-6664b5ed2609> in <module>
# ----> 1 clip_points_by_ecoregion(shp_files[0], list(groups)[0], output_folder)
#
# D:\projects\RD\night_fire\notebooks\helpers.py in clip_points_by_ecoregion(points_filepath, group, out_folder)
#     197
#     198     # clip the files
# --> 199     sub_df = clip_shp(pts_df, eco_df)
#     200
#     201     # save it
#
# C:\software\anaconda3\envs\eapy_gbdx\lib\site-packages\earthpy\clip.py in clip_shp(shp, clip_obj)
#     150     if "Multi" in str(clip_obj.geom_type) or "Multi" in str(shp.geom_type):
#     151         raise ValueError(
# --> 152             "Clip doesn't currently support multipart geometries. Consider "
#     153             "using .explode to create unique features in your GeoDataFrame"
#     154         )
#
# ValueError: Clip doesn't currently support multipart geometries. Consider using .explode to create unique features in your GeoDataFrame

# %%
test.to_file('../ecoregions_L1_CONUS.shp')
# Out:
# C:\software\anaconda3\envs\eapy_gbdx\lib\site-packages\geopandas\io\file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
test.head()
# Out:
#    index NA_L1CODE                  NA_L1NAME                      NA_L1KEY  \
# 0   2002         8  EASTERN TEMPERATE FORESTS  8  EASTERN TEMPERATE FORESTS
# 1   2014         8  EASTERN TEMPERATE FORESTS  8  EASTERN TEMPERATE FORESTS
# 2   2015         8  EASTERN TEMPERATE FORESTS  8  EASTERN TEMPERATE FORESTS
# 3   2019         8  EASTERN TEMPERATE FORESTS  8  EASTERN TEMPERATE FORESTS
# 4   2028         8  EASTERN TEMPERATE FORESTS  8  EASTERN TEMPERATE FORESTS
#
#       Shape_Leng    Shape_Area  \
# 0    2293.192372  3.374335e+05
# 1   33292.842298  7.308003e+06
# 2    6874.214627  7.997862e+05
# 3  101816.915189  2.537028e+07
# 4   15708.177112  2.841671e+06
#
#                                             geometry
# 0  POLYGON ((-7818493.630414151 5417164.019218392...
# 1  POLYGON ((-7786599.018038419 5432578.144002809...
# 2  (POLYGON ((-7783035.451414463 5432482.60428471...
# 3  (POLYGON ((-7780295.298771944 5443353.24114592...
# 4  POLYGON ((-7742068.185564543 5444572.93132353,...
