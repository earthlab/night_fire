# %%
import pickle
import pandas as pd
from matplotlib import pyplot as plt

# %%
with open('mp_result.pickle', 'rb') as f:
    a = pickle.load(f)

# %%
a
# Out:
# [('y2000', 181258, 32465),
#  ('y2001', 1132077, 291551),
#  ('y2002', 2514300, 449339),
#  ('y2003', 3660353, 469640),
#  ('y2004', 3621212, 478857),
#  ('y2005', 3638143, 486618),
#  ('y2006', 3339248, 430239),
#  ('y2007', 3643010, 498586),
#  ('y2008', 3486630, 393640),
#  ('y2009', 3212997, 371464),
#  ('y2010', 3330229, 459849),
#  ('y2012', 3440429, 522539),
#  ('y2013', 3025981, 354973),
#  ('y2014', 3123710, 412880),
#  ('y2015', 3308406, 484942),
#  ('y2016', 3118733, 410105),
#  ('y2017', 3112795, 457871),
#  ('y2018', 2954998, 397293),
#  ('y2019', 849627, 114123)]

# %%
yr = [int(i[0][1:]) for i in a]
day_cts = [i[1] for i in a]
night_cts = [i[2] for i in a]

# %%
df = pd.DataFrame({'year': yr, 'day_counts':day_cts, 'night_counts':night_cts})

# %%
df
# Out:
#     year  day_counts  night_counts
# 0   2000      181258         32465
# 1   2001     1132077        291551
# 2   2002     2514300        449339
# 3   2003     3660353        469640
# 4   2004     3621212        478857
# 5   2005     3638143        486618
# 6   2006     3339248        430239
# 7   2007     3643010        498586
# 8   2008     3486630        393640
# 9   2009     3212997        371464
# 10  2010     3330229        459849
# 11  2012     3440429        522539
# 12  2013     3025981        354973
# 13  2014     3123710        412880
# 14  2015     3308406        484942
# 15  2016     3118733        410105
# 16  2017     3112795        457871
# 17  2018     2954998        397293
# 18  2019      849627        114123

# %%
ax = df.plot(y='day_counts', x='year', label='day')
df.plot(y='night_counts', x='year', ax=ax, label='night')
# plt.legend('upper left')

# %%
df.plot(kind='bar', x='year', y=['day_counts', 'night_counts'], 
        figsize=(20,10), rot=15, alpha=0.5, edgecolor='k',
       title='Total Annual FIRMS fire counts > 50% confidence', fontsize=12)

# %%
df_perc = df.copy()

# %%
df_perc['total_counts'] = df_perc['day_counts'] + df_perc['night_counts']
df_perc['night_perc'] = df_perc['night_counts'] / df_perc['total_counts']
df_perc
# Out:
#     year  day_counts  night_counts  total_counts  night_perc
# 0   2000      181258         32465        213723    0.151902
# 1   2001     1132077        291551       1423628    0.204794
# 2   2002     2514300        449339       2963639    0.151617
# 3   2003     3660353        469640       4129993    0.113714
# 4   2004     3621212        478857       4100069    0.116792
# 5   2005     3638143        486618       4124761    0.117975
# 6   2006     3339248        430239       3769487    0.114137
# 7   2007     3643010        498586       4141596    0.120385
# 8   2008     3486630        393640       3880270    0.101447
# 9   2009     3212997        371464       3584461    0.103632
# 10  2010     3330229        459849       3790078    0.121330
# 11  2012     3440429        522539       3962968    0.131855
# 12  2013     3025981        354973       3380954    0.104992
# 13  2014     3123710        412880       3536590    0.116745
# 14  2015     3308406        484942       3793348    0.127840
# 15  2016     3118733        410105       3528838    0.116215
# 16  2017     3112795        457871       3570666    0.128231
# 17  2018     2954998        397293       3352291    0.118514
# 18  2019      849627        114123        963750    0.118416
